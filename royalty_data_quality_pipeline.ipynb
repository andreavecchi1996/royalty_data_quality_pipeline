# %% [markdown]
# ## Libraries Setup

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## cvs Files import

# %%
df_amazon_jan24_raw = pd.read_csv('inbound_reports/amazon_jan24_raw.csv')
df_amazon_jan24_raw.head()
# Out:
#            ArtistName                                 LabelName  \
# 0    Heather Campbell            Thompson-Kennedy Entertainment
# 1       Claire Nelson                             Merge Records
# 2       Carlos Mcneil                          Red Bull Records
# 3  Cole and the Foods      Underground Leblanc-Smith Recordings
# 4   Shawn Hoffman DVM  Price, Bowers and Campbell Entertainment
#
#                                       TrackTitle          ISRC  \
# 0                      Ergonomic Mobile Matrices  SEPCQ2078164
# 1  Distributed Human-Resource Encryption (Remix)  US0RP2132653
# 2          Balanced Asynchronous Circuit (Remix)  USU1B1999467
# 3             Exclusive Even-Keeled Service-Desk  USYI42092764
# 4                      Synchronized Modular Core  NL8482350277
#
#                                 AlbumTitle            UPC CountryCode  \
# 0         Incentivize Out-Of-The-Box Users  3615792141804          CO
# 1  Whiteboard End-To-End Networks - Single  7036509867998          FR
# 2             Disintermediate B2C Networks  7033698387288          JP
# 3             Monetize Granular E-Services   846056613526          PL
# 4            Streamline Extensible Markets  6579146561035          NL
#
#   Service_Tier  PlayCount  Royalty CurrencyCode Period_Start  Period_End  \
# 0        Prime          2     0.00          USD   2024-01-01  2024-01-31
# 1        Prime        117     0.25          EUR   2024-01-01  2024-01-31
# 2    Unlimited         54    19.50          JPY   2024-01-01  2024-01-31
# 3    Unlimited          2     0.01          USD   2024-01-01  2024-01-31
# 4    Unlimited         93     0.58          EUR   2024-01-01  2024-01-31
#
#          ASIN
# 0  B0Z3ZJ1TNM
# 1  B0GRPWSETW
# 2  B0930A65T4
# 3  B0DWLW5S0Z
# 4  B00HDF9OUV

# %%
df_amazon_feb24_raw = pd.read_csv('inbound_reports/amazon_feb24_raw.csv')
df_amazon_feb24_raw.head()
# Out:
#            ArtistName                                 LabelName  \
# 0    Heather Campbell            Thompson-Kennedy Entertainment
# 1       Claire Nelson                             Merge Records
# 2       Carlos Mcneil                          Red Bull Records
# 3  Cole and the Foods      Underground Leblanc-Smith Recordings
# 4   Shawn Hoffman DVM  Price, Bowers and Campbell Entertainment
#
#                                       TrackTitle          ISRC  \
# 0                      Ergonomic Mobile Matrices  SEPCQ2078164
# 1  Distributed Human-Resource Encryption (Remix)  US0RP2132653
# 2          Balanced Asynchronous Circuit (Remix)  USU1B1999467
# 3             Exclusive Even-Keeled Service-Desk  USYI42092764
# 4                      Synchronized Modular Core  NL8482350277
#
#                                 AlbumTitle            UPC CountryCode  \
# 0         Incentivize Out-Of-The-Box Users  3615792141804          CO
# 1  Whiteboard End-To-End Networks - Single  7036509867998          FR
# 2             Disintermediate B2C Networks  7033698387288          JP
# 3             Monetize Granular E-Services   846056613526          PL
# 4            Streamline Extensible Markets  6579146561035          NL
#
#   Service_Tier  PlayCount  Royalty CurrencyCode Period_Start  Period_End  \
# 0    Unlimited          7     0.03          USD   2024-02-01  2024-02-29
# 1    Unlimited        639     2.30          EUR   2024-02-01  2024-02-29
# 2    Unlimited          8     4.50          JPY   2024-02-01  2024-02-29
# 3        Prime          1     0.00          USD   2024-02-01  2024-02-29
# 4        Prime        197     0.50          EUR   2024-02-01  2024-02-29
#
#          ASIN
# 0  B0NEBQOFGD
# 1  B0EO4NI1LB
# 2  B0PDDQSGA8
# 3  B08G93NXY3
# 4  B0B9F2O0ER
