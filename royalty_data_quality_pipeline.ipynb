# %% [markdown]
# ## Libraries Setup

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## cvs Files import

# %%
df_amazon_jan24_raw = pd.read_csv('inbound_reports/amazon_jan24_raw.csv')
df_amazon_jan24_raw.head()
# Out:
#                 ArtistName          LabelName  \
# 0           Walters & Sosa   Redeye Worldwide
# 1   Moore and the Managers        Dead Oceans
# 2  Gomez and the Behaviors   Gray Inc Records
# 3           Shannon Wilson             [PIAS]
# 4             Sandra Owens  Moore Inc Records
#
#                                TrackTitle          ISRC  \
# 0        Synchronized Clear-Thinking Core  DE3NL2489870
# 1  Optional Static Support (Extended Mix)  SE0DU1971111
# 2   Reverse-Engineered Bifurcated Synergy  FRR722046432
# 3        Horizontal Local Standardization  USMCK2091254
# 4          Cloned System-Worthy Algorithm  NL0X12366321
#
#                                AlbumTitle           UPC CountryCode  \
# 0  Repurpose Frictionless E-Business - EP  9.885830e+12          CO
# 1           Enhance Wireless Deliverables  6.491991e+11          JP
# 2         Brand Frictionless Applications  2.893330e+12          SE
# 3          Exploit User-Centric Solutions  1.854620e+12          AU
# ...

# %%
df_amazon_feb24_raw = pd.read_csv('inbound_reports/amazon_feb24_raw.csv')
df_amazon_feb24_raw.head()
# Out:
#                  ArtistName                        LabelName  \
# 0               Sara Guzman                 Lopez Recordings
# 1  Wilkerson and the Readys  Roberson, Ellis and Henry Label
# 2     Walker and the Thinks                  Dim Mak Records
# 3              Hill & Nolan             Pure Williams, Music
# 4                Big Martin                 Gray Inc Records
#
#                                      TrackTitle          ISRC  \
# 0                   Right-Sized Local Challenge  NLKSG2310725
# 1               Versatile Interactive Hierarchy  GB6921858245
# 2                  Multi-Tiered Global Alliance  GBOJC2378105
# 3  Synergistic Exuding Moderator (Extended Mix)  USURC1924388
# 4         Automated Real-Time Capability (Live)  US3HF2414236
#
#                                    AlbumTitle           UPC CountryCode  \
# 0               Target Value-Added E-Services  7.787640e+12          SE
# 1             Harness Strategic Relationships  9.824450e+12          PL
# ...

# %%
df_amazon_mar24_raw = pd.read_csv('inbound_reports/amazon_mar24_raw.csv')
df_amazon_mar24_raw.head()
# Out:
#                  ArtistName                        LabelName  \
# 0                 Big Russo               Better Noise Music
# 1           Schultz & Brown             Pure Williams, Music
# 2  Pennington and the Saves  Hunter, Sampson and Flynn Label
# 3               Nancy Watts                    Merge Records
# 4           Bright & Warren                  Raw Six Records
#
#                                      TrackTitle          ISRC  \
# 0                  Universal Holistic Help-Desk  SEJ0Q2077055
# 1          Advanced Disintermediate Focus Group  SEMLT2417008
# 2               Pre-Emptive Executive Migration  DEBDS1963884
# 3  Triple-Buffered Zero Administration Intranet  DE9IG1889119
# 4                    Integrated Analyzing Model  DEH5G2136029
#
#                                           AlbumTitle           UPC  \
# 0                          Morph Rich E-Tailers - EP  8.828410e+12
# 1           Re-Intermediate User-Centric Convergence  5.224710e+12
# ...

# %%
df_apple_jan24_raw = pd.read_csv('inbound_reports/apple_jan24_raw.csv')
df_apple_jan24_raw.head()
# Out:
#                  Artist                      Label  \
# 0      Luna & Cervantes  Pure Conway-David Records
# 1  Jacqueline Gutierrez                Dead Oceans
# 2    Miller & Castaneda      Wilkinson, Recordings
# 3       Jones & Montoya           Martinez, Sounds
# 4          Sarah Mccann           Lopez Recordings
#
#                                  Song_Title          ISRC  \
# 0         Front-Line Multi-Tasking Paradigm  SER6N2360724
# 1                    Digitized Optimal Core  GBVNH2445772
# 2             Intuitive Didactic Complexity  DEYY42341711
# 3  Configurable Multi-Tasking Collaboration  FRTUT2216870
# 4            Horizontal Stable Productivity  USTDZ2372394
#
#                                             Album           UPC Territory  \
# 0                         Deploy Global Paradigms  6.871430e+12        DE
# 1                  Expedite Synergistic Synergies  8.006070e+12        NO
# 2  Re-Intermediate Value-Added E-Markets - Single  9.708640e+12        AR
# ...

# %%
df_apple_feb24_raw = pd.read_csv('inbound_reports/apple_feb24_raw.csv')
df_apple_feb24_raw.head()
# Out:
#                 Artist                             Label  \
# 0          Lil Lindsey                   Pure Pick Music
# 1     Harper & Goodman                True Guzman, Audio
# 2   Christopher Turner  Burns, Jensen and Martinez Music
# 3     Jennifer Leblanc              Pure Live Recordings
# 4  Clark and the Thens                       !K7 Records
#
#                                           Song_Title          ISRC  \
# 0                    Digitized Bifurcated Projection           NaN
# 1                  Robust Leadingedge Data-Warehouse  SERBA2186976
# 2  Cross-Group Fault-Tolerant Artificial Intellig...  DE7E41920815
# 3     Focused Maximized Pricing Structure (Acoustic)  SE36F2235401
# 4              Multi-Channeled Heuristic Parallelism  NLNPO2456494
#
#                                        Album           UPC Territory  \
# 0                Unleash Wireless Users - EP  4.358440e+12        AR
# 1          Implement E-Business Technologies  9.586190e+12        IT
# ...

# %%
df_apple_mar24_raw = pd.read_csv('inbound_reports/apple_mar24_raw.csv')
df_apple_mar24_raw.head()
# Out:
#                     Artist                                  Label  \
# 0               DJ Parrish                       Redeye Worldwide
# 1            Jenna Sanchez  Simpson, Patel and Barajas Recordings
# 2    Mr. William Young DDS                                   FUGA
# 3  Hines and the Decisions                       Pure Walsh Audio
# 4        Jimenez & Jackson                            Glass Tapes
#
#                                     Song_Title          ISRC  \
# 0            Public-Key System-Worthy Encoding  NLMED1971596
# 1             Extended Real-Time System Engine  SE5IO2054647
# 2             Digitized System-Worthy Hardware  USKHC2432610
# 3        Pre-Emptive Asymmetric Implementation  US2XG1969418
# 4  Cross-Group Mission-Critical Conglomeration  NL7JO2368972
#
#                              Album           UPC Territory Subscription_Type  \
# 0            Seize 24/365 Networks  2.224610e+12        GB        Individual
# ...

# %%
df_deezer_jan24_raw = pd.read_csv('inbound_reports/deezer_jan24_raw.csv')
df_deezer_jan24_raw.head()
# Out:
#                      Artiste                             Label  \
# 0     Walker and the Commons                 Green PLC Records
# 1  Martinez and the Teachers            Carroll-Alvarado Label
# 2              The Suddenlys            Carroll-Alvarado Label
# 3      Davis and the Degrees          True Perez-Pittman Audio
# 4                 Big Turner  Bridges, Kelley and Hanson Label
#
#                                                Titre          ISRC  \
# 0              Progressive Bi-Directional Projection  FREOV2232082
# 1  Universal System-Worthy Conglomeration (Acoustic)  FR2DK1874809
# 2                              User-Centric 24/7 Hub  GBMHR2438777
# 3     Fully-Configurable Leadingedge Core (Acoustic)  FRO8B2413981
# 4   Public-Key Bandwidth-Monitored Challenge (Remix)  GBX582399854
#
#                                  Album           UPC Pays Type_Compte  \
# 0  Integrate Distributed Web-Readiness  9.301136e+11   PL        Free
# ...

# %%
df_deezer_feb24_raw = pd.read_csv('inbound_reports/deezer_feb24_raw.csv')
df_deezer_feb24_raw.head()
# Out:
#           Artiste                            Label  \
# 0    Levine & Lee                Green PLC Records
# 1        MC Olson               Brown, Productions
# 2  Harris & Bryan            Parker and Sons Music
# 3     Adam Wright  Lynch, Torres and Stewart Label
# 4  Weber & Knight             True Collins Records
#
#                                          Titre          ISRC  \
# 0                                          NaN  NLPK72263871
# 1                Inverse Disintermediate Frame  SE8TC2313753
# 2            Enhanced Client-Server Neural-Net  DELHE2290055
# 3        Right-Sized Grid-Enabled Productivity  NL6NG2275814
# 4  Organized Even-Keeled Strategy (Radio Edit)  FRNJV2215322
#
#                                  Album           UPC Pays Type_Compte  \
# 0     Iterate Out-Of-The-Box E-Markets  3.327840e+12   BR     Premium
# 1      Grow Clicks-And-Mortar Eyeballs  9.796790e+12   IT     Premium
# 2  Transition Distributed Systems - EP  4.928930e+12   AU     Premium
# ...

# %%
df_deezer_mar24_raw = pd.read_csv('inbound_reports/deezer_mar24_raw.csv')
df_deezer_mar24_raw.head()
# Out:
#                 Artiste                            Label  \
# 0          Samuel Evans  Underground Wheeler, Recordings
# 1     Cox and the Walks          Underground Olson Music
# 2         Nichols & Lin           New Walton-Evans Audio
# 3  Garcia and the Notes                     Idea Records
# 4           Jane Hudson                             FUGA
#
#                                                Titre          ISRC  \
# 0  Focused Object-Oriented Graphical User Interfa...  FREFN2370500
# 1                        Sharable Holistic Workforce  FRNQK2361139
# 2               Seamless 5Thgeneration Model (Remix)  GBMQ82154356
# 3   Triple-Buffered Multimedia Strategy (Radio Edit)  FRGDW2464820
# 4             Persistent Optimizing Algorithm (Live)  DES8P1950413
#
#                                    Album           UPC Pays Type_Compte  \
# 0           Deploy Leading-Edge Channels  4.307650e+12   FR     Premium
# ...

# %%
df_spotify_jan24_raw = pd.read_csv('inbound_reports/spotify_jan24_raw.csv')
df_spotify_jan24_raw.head()
# Out:
#                  artist_name                             label_name  \
# 0             Wiggins & Ball                           Warp Records
# 1                Lee & Chung             Harris-Greer Entertainment
# 2              Allen Hickman  Johnson, Harrell and Holt Music Group
# 3  Anderson and the Companys                    Bridges Group Label
# 4       Christopher Hamilton                       Redeye Worldwide
#
#                              track_title          isrc  \
# 0        Function-Based Mobile Challenge  NLSXD1849510
# 1                 Managed Foreground Hub  USMT51887504
# 2                Adaptive 24Hour Synergy  SE5V02042244
# 3  Sharable Hybrid Knowledge User (Live)  DE19Z2079434
# 4          Proactive Responsive Forecast  GB4H82295591
#
#                                    album_title           upc country_code  \
# 0  Re-Contextualize Integrated Infrastructures  3.420405e+11           CA
# ...

# %%
df_spotify_feb24_raw = pd.read_csv('inbound_reports/spotify_feb24_raw.csv')
df_spotify_feb24_raw.head()
# Out:
#            artist_name              label_name  \
# 0  Hall and the Abouts  Symphonic Distribution
# 1  Singleton & Ballard    Polyvinyl Record Co.
# 2  Lee and the Churchs  Symphonic Distribution
# 3         Karen Ibarra              Wood Music
# 4          Diaz & King  Montgomery Group Music
#
#                                         track_title          isrc  \
# 0                  Front-Line Regional Service-Desk  FR59O1839718
# 1    Vision-Oriented 5Thgeneration Capacity (Remix)  FR9FM1882596
# 2                    Reactive Client-Driven Project  US0QK2258798
# 3  Fundamental Fresh-Thinking Capability (Acoustic)  GB7PT2285311
# 4                    Persistent Asymmetric Capacity  FRZ172168817
#
#                              album_title           upc country_code  \
# 0  Engineer Cross-Media Schemas - Single  2.064650e+12           JP
# 1         Evolve Web-Enabled Communities  9.008470e+12           FR
# 2       Synthesize Open-Source E-Tailers  6.522880e+12           NL
# ...

# %%
df_spotify_mar24_raw = pd.read_csv('inbound_reports/spotify_mar24_raw.csv')
df_spotify_mar24_raw.head()
# Out:
#              artist_name                  label_name  \
# 0            Chloe Roach      Montgomery Group Music
# 1             Roy Martin            True Some Sounds
# 2            Joshua Wood  Harris-Greer Entertainment
# 3        Daniels & Velez          Raw Parsons Sounds
# 4  Clark and the Becomes        Randolph Inc Records
#
#                                   track_title          isrc  \
# 0       Upgradable Context-Sensitive Leverage  FRDC52372518
# 1  Business-Focused Object-Oriented Interface  DEVNP1982135
# 2        Polarized Content-Based Architecture  SEYK62268118
# 3   Synergistic Contextually-Based Encryption  GBW9H2127704
# 4  Digitized Mission-Critical Instruction Set  FR51P1928235
#
#                            album_title           upc country_code stream_type  \
# 0        Generate Visionary Interfaces  2.140480e+12           PL        Free
# 1      Incubate Scalable Methodologies  3.770980e+12           GB     Premium
# ...

# %%
df_youtube_jan24_raw = pd.read_csv('inbound_reports/youtube_jan24_raw.csv')
df_youtube_jan24_raw.head()
# Out:
#           Channel_Name        Rights_Owner  \
# 0          Luna & Bell   Moore Inc Records
# 1           The Majors  True Cochran Tapes
# 2       Kathryn Benson   Brown, Recordings
# 3  Sullivan & Martinez    Red Bull Records
# 4          Big Rosales   Secretly Canadian
#
#                                  Video_Title    Asset_ISRC  \
# 0       Progressive Fresh-Thinking Emulation  NL9KH2153111
# 1  Business-Focused Dynamic Customer Loyalty  FRTGP2018816
# 2              Operative Exuding Focus Group  SES2Z2255756
# 3  Quality-Focused Mission-Critical Strategy  SEF1E2218977
# 4           Customizable Real-Time Benchmark  FREB51823022
#
#                           Album_Title     Asset_UPC Country_of_Sale  \
# 0  Mesh Innovative E-Tailers - Single  8.545080e+12              KR
# 1    Optimize Cross-Media Initiatives  9.444060e+12              US
# 2          Unleash Viral Partnerships  3.362882e+11              GB
# 3          Architect Global Paradigms  4.280615e+11              KR
# ...

# %%
df_youtube_feb24_raw = pd.read_csv('inbound_reports/youtube_feb24_raw.csv')
df_youtube_feb24_raw.head()
# Out:
#                  Channel_Name                         Rights_Owner  \
# 0          Escobar & Franklin                    Secretly Canadian
# 1  Sutton and the Investments                                 FUGA
# 2            Murphy & Russell  Salas, Williamson and Wallace Label
# 3            Jacqueline Ramos                          !K7 Records
# 4             Wallace & Davis                   Raw Johnson Sounds
#
#                                      Video_Title    Asset_ISRC  \
# 0  Cross-Platform Dynamic Workforce (Radio Edit)  GBZJC2215364
# 1                    Phased Secondary Task-Force  DEKNT1914787
# 2              Balanced Zero Tolerance Groupware  US4Q81877453
# 3       Assimilated Context-Sensitive Capability  GBGH62024733
# 4                      Persevering Hybrid Matrix  SEYP61916035
#
#                                 Album_Title     Asset_UPC Country_of_Sale  \
# 0     Iterate Compelling Web-Readiness - EP  2.941310e+12              NO
# ...

# %%
df_youtube_mar24_raw = pd.read_csv('inbound_reports/youtube_mar24_raw.csv')
df_youtube_mar24_raw.head()
# Out:
#                Channel_Name               Rights_Owner  \
# 0               Big Kaufman         Raw Art Recordings
# 1  Hensley and the Specials                Singh Music
# 2    Stewart and the Untils                      Anti-
# 3      Montgomery & Hampton  Underground Often Records
# 4               Big Perkins                 Main Tapes
#
#                           Video_Title    Asset_ISRC  \
# 0         Focused Regional Middleware  GBKH01915309
# 1  Reactive Client-Driven Flexibility  SEXXV1847606
# 2        Realigned Executive Forecast  FRRAD2456733
# 3              Compatible Local Array  SEIVK2261904
# 4  Vision-Oriented Actuating Database  FRIBT2224778
#
#                                    Album_Title     Asset_UPC Country_of_Sale  \
# 0                 Whiteboard Dot-Com Synergies  5.202790e+12              US
# 1           Visualize End-To-End Methodologies  6.078590e+12              AU
# 2  Facilitate One-To-One Web Services - Single  2.225960e+12              NO
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## cvs dfs check

# %%
df_amazon_jan24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ArtistName    150000 non-null  object
#  1   LabelName     149998 non-null  object
#  2   TrackTitle    150000 non-null  object
#  3   ISRC          149996 non-null  object
#  4   AlbumTitle    150000 non-null  object
#  5   UPC           150000 non-null  float64
#  6   CountryCode   150000 non-null  object
#  7   Service_Tier  150000 non-null  object
#  8   PlayCount     150000 non-null  int64
#  9   Royalty       150000 non-null  float64
#  10  CurrencyCode  150000 non-null  object
#  11  Period_Start  150000 non-null  object
#  12  Period_End    150000 non-null  object
#  13  ASIN          150000 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 16.0+ MB

# %% [markdown]
# - 4 'ISRC' null
# - 2 'LabelName' null

# %%
df_amazon_feb24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ArtistName    150000 non-null  object
#  1   LabelName     150000 non-null  object
#  2   TrackTitle    150000 non-null  object
#  3   ISRC          150000 non-null  object
#  4   AlbumTitle    150000 non-null  object
#  5   UPC           150000 non-null  float64
#  6   CountryCode   150000 non-null  object
#  7   Service_Tier  150000 non-null  object
#  8   PlayCount     150000 non-null  int64
#  9   Royalty       150000 non-null  float64
#  10  CurrencyCode  150000 non-null  object
#  11  Period_Start  150000 non-null  object
#  12  Period_End    150000 non-null  object
#  13  ASIN          150000 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 16.0+ MB

# %%
df_amazon_mar24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ArtistName    150000 non-null  object
#  1   LabelName     150000 non-null  object
#  2   TrackTitle    149997 non-null  object
#  3   ISRC          150000 non-null  object
#  4   AlbumTitle    150000 non-null  object
#  5   UPC           150000 non-null  float64
#  6   CountryCode   150000 non-null  object
#  7   Service_Tier  150000 non-null  object
#  8   PlayCount     150000 non-null  int64
#  9   Royalty       150000 non-null  float64
#  10  CurrencyCode  150000 non-null  object
#  11  Period_Start  150000 non-null  object
#  12  Period_End    150000 non-null  object
#  13  ASIN          150000 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 16.0+ MB

# %% [markdown]
# - 3 'TrackTitle' null

# %%
df_apple_jan24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Artist             150000 non-null  object
#  1   Label              150000 non-null  object
#  2   Song_Title         150000 non-null  object
#  3   ISRC               150000 non-null  object
#  4   Album              150000 non-null  object
#  5   UPC                150000 non-null  float64
#  6   Territory          150000 non-null  object
#  7   Subscription_Type  150000 non-null  object
#  8   Plays              150000 non-null  int64
#  9   Earnings           150000 non-null  float64
#  10  Currency_Code      150000 non-null  object
#  11  Report_Start_Date  150000 non-null  object
#  12  Report_End_Date    150000 non-null  object
#  13  Apple_ID           150000 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 16.0+ MB

# %%
df_apple_feb24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Artist             150000 non-null  object
#  1   Label              149996 non-null  object
#  2   Song_Title         149986 non-null  object
#  3   ISRC               149983 non-null  object
#  4   Album              149999 non-null  object
#  5   UPC                150000 non-null  float64
#  6   Territory          150000 non-null  object
#  7   Subscription_Type  150000 non-null  object
#  8   Plays              150000 non-null  int64
#  9   Earnings           150000 non-null  float64
#  10  Currency_Code      150000 non-null  object
#  11  Report_Start_Date  150000 non-null  object
#  12  Report_End_Date    150000 non-null  object
#  13  Apple_ID           150000 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 16.0+ MB

# %% [markdown]
# - 4 'Label' null
# - 12 'Song_Title' null
# - 17 'ISRC' null
# - 1 'Album' null

# %%
df_apple_mar24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Artist             149999 non-null  object
#  1   Label              149994 non-null  object
#  2   Song_Title         149996 non-null  object
#  3   ISRC               149996 non-null  object
#  4   Album              150000 non-null  object
#  5   UPC                150000 non-null  float64
#  6   Territory          150000 non-null  object
#  7   Subscription_Type  150000 non-null  object
#  8   Plays              150000 non-null  int64
#  9   Earnings           150000 non-null  float64
#  10  Currency_Code      150000 non-null  object
#  11  Report_Start_Date  150000 non-null  object
#  12  Report_End_Date    150000 non-null  object
#  13  Apple_ID           150000 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 16.0+ MB

# %% [markdown]
# - 1 'Artist' null
# - 4 'Label' null
# - 4 'Song_Title' null
# - 4 'ISRC' null

# %%
df_deezer_jan24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Artiste          149998 non-null  object
#  1   Label            149997 non-null  object
#  2   Titre            149998 non-null  object
#  3   ISRC             150000 non-null  object
#  4   Album            149998 non-null  object
#  5   UPC              149999 non-null  float64
#  6   Pays             150000 non-null  object
#  7   Type_Compte      150000 non-null  object
#  8   Ecoutes          150000 non-null  int64
#  9   Revenus          150000 non-null  float64
#  10  Devise           150000 non-null  object
#  11  Date_Debut       150000 non-null  object
#  12  Date_Fin         150000 non-null  object
#  13  Deezer_Track_ID  150000 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 16.0+ MB

# %% [markdown]
# - 2 'Artiste' null
# - 3 'Label' null
# - 2 'Titre' null
# - 2 'Album' null
# - 1 'UPC' null

# %%
df_deezer_feb24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Artiste          149996 non-null  object
#  1   Label            149994 non-null  object
#  2   Titre            149998 non-null  object
#  3   ISRC             149996 non-null  object
#  4   Album            149998 non-null  object
#  5   UPC              149999 non-null  float64
#  6   Pays             150000 non-null  object
#  7   Type_Compte      150000 non-null  object
#  8   Ecoutes          150000 non-null  int64
#  9   Revenus          150000 non-null  float64
#  10  Devise           150000 non-null  object
#  11  Date_Debut       150000 non-null  object
#  12  Date_Fin         150000 non-null  object
#  13  Deezer_Track_ID  150000 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 16.0+ MB

# %% [markdown]
# - 4 Artiste null
# - 6 Label null
# - 2 Titre null
# - 4 ISRC null
# - 2 Album null
# - 1 UPC null

# %%
df_deezer_mar24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Artiste          149999 non-null  object
#  1   Label            150000 non-null  object
#  2   Titre            149999 non-null  object
#  3   ISRC             149998 non-null  object
#  4   Album            150000 non-null  object
#  5   UPC              150000 non-null  float64
#  6   Pays             150000 non-null  object
#  7   Type_Compte      150000 non-null  object
#  8   Ecoutes          150000 non-null  int64
#  9   Revenus          150000 non-null  float64
#  10  Devise           150000 non-null  object
#  11  Date_Debut       150000 non-null  object
#  12  Date_Fin         150000 non-null  object
#  13  Deezer_Track_ID  150000 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 16.0+ MB

# %% [markdown]
# - 1 Artiste null
# - 1 Titre null
# - 2 ISRC null

# %%
df_spotify_jan24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   artist_name     149994 non-null  object
#  1   label_name      149995 non-null  object
#  2   track_title     149997 non-null  object
#  3   isrc            149996 non-null  object
#  4   album_title     149999 non-null  object
#  5   upc             150000 non-null  float64
#  6   country_code    150000 non-null  object
#  7   stream_type     150000 non-null  object
#  8   streams         150000 non-null  int64
#  9   royalty_amount  150000 non-null  float64
#  10  currency        150000 non-null  object
#  11  period_start    150000 non-null  object
#  12  period_end      150000 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 14.9+ MB

# %% [markdown]
# - 6 artist_name null
# - 5 label_name null
# - 3 track_title null
# - 4 isrc null
# - 1 album_title null

# %%
df_spotify_feb24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   artist_name     149996 non-null  object
#  1   label_name      149998 non-null  object
#  2   track_title     149997 non-null  object
#  3   isrc            149998 non-null  object
#  4   album_title     149996 non-null  object
#  5   upc             150000 non-null  float64
#  6   country_code    150000 non-null  object
#  7   stream_type     150000 non-null  object
#  8   streams         150000 non-null  int64
#  9   royalty_amount  150000 non-null  float64
#  10  currency        150000 non-null  object
#  11  period_start    150000 non-null  object
#  12  period_end      150000 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 14.9+ MB

# %% [markdown]
# - 4 artist_name null
# - 2 label_name null
# - 3 track_title null
# - 2 isrc null
# - 4 album_title null

# %%
df_spotify_mar24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   artist_name     149996 non-null  object
#  1   label_name      149995 non-null  object
#  2   track_title     149996 non-null  object
#  3   isrc            150000 non-null  object
#  4   album_title     149998 non-null  object
#  5   upc             150000 non-null  float64
#  6   country_code    150000 non-null  object
#  7   stream_type     150000 non-null  object
#  8   streams         150000 non-null  int64
#  9   royalty_amount  150000 non-null  float64
#  10  currency        150000 non-null  object
#  11  period_start    150000 non-null  object
#  12  period_end      150000 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 14.9+ MB

# %% [markdown]
# - 4 artist_name null
# - 5 label_name null
# - 6 track_title null
# - 2 album_title null

# %%
df_youtube_jan24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Channel_Name       149997 non-null  object
#  1   Rights_Owner       150000 non-null  object
#  2   Video_Title        149997 non-null  object
#  3   Asset_ISRC         149999 non-null  object
#  4   Album_Title        149997 non-null  object
#  5   Asset_UPC          149997 non-null  float64
#  6   Country_of_Sale    150000 non-null  object
#  7   Content_Type       150000 non-null  object
#  8   Views              150000 non-null  int64
#  9   Estimated_Revenue  150000 non-null  float64
#  10  Currency           150000 non-null  object
#  11  Start_Date         150000 non-null  object
#  12  End_Date           150000 non-null  object
#  13  Video_ID           150000 non-null  object
#  14  Asset_ID           150000 non-null  object
# ...

# %% [markdown]
# - 3 Channel_Name null
# - 3 Video_Title null
# - 1 Asset_ISRC null
# - 3 Album_Title null
# - 3 Asset_UPC null

# %%
df_youtube_feb24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Channel_Name       149992 non-null  object
#  1   Rights_Owner       149997 non-null  object
#  2   Video_Title        149996 non-null  object
#  3   Asset_ISRC         149999 non-null  object
#  4   Album_Title        149998 non-null  object
#  5   Asset_UPC          149998 non-null  float64
#  6   Country_of_Sale    150000 non-null  object
#  7   Content_Type       150000 non-null  object
#  8   Views              150000 non-null  int64
#  9   Estimated_Revenue  150000 non-null  float64
#  10  Currency           150000 non-null  object
#  11  Start_Date         150000 non-null  object
#  12  End_Date           150000 non-null  object
#  13  Video_ID           150000 non-null  object
#  14  Asset_ID           150000 non-null  object
# ...

# %% [markdown]
# - 8 'Channel_Name' null
# - 3 'Rights_Owner' null
# - 4 'Video_Title null
# - 1 'Asset_ISRC' null
# - 2 'Album_Title' null
# - 2 'Asset_UPC' null

# %%
df_youtube_mar24_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Channel_Name       149996 non-null  object
#  1   Rights_Owner       149998 non-null  object
#  2   Video_Title        150000 non-null  object
#  3   Asset_ISRC         149998 non-null  object
#  4   Album_Title        149997 non-null  object
#  5   Asset_UPC          150000 non-null  float64
#  6   Country_of_Sale    150000 non-null  object
#  7   Content_Type       150000 non-null  object
#  8   Views              150000 non-null  int64
#  9   Estimated_Revenue  150000 non-null  float64
#  10  Currency           150000 non-null  object
#  11  Start_Date         150000 non-null  object
#  12  End_Date           150000 non-null  object
#  13  Video_ID           150000 non-null  object
#  14  Asset_ID           150000 non-null  object
# ...

# %% [markdown]
# - 4 'Channel_Name' null
# - 2 'Rights_Owner' null
# - 2 'Asset_ISRC' null
# - 3 'Album_Title' null
